# %% [markdown]
# # Tarefa I
#
# Neste projeto, estamos construindo um credit scoring para cartão de crédito, em um desenho amostral com 15 safras, e utilizando 12 meses de performance.
#
# Carregue a base de dados ```credit_scoring.ftr```.

# %%
#pip install pycaret

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

import statsmodels.formula.api as smf
import statsmodels.api as sm

import warnings ; warnings.filterwarnings('ignore')

from sklearn import metrics
from scipy.stats import ks_2samp
from scipy.stats import t
from sklearn.metrics._scorer import _Scorer
from pycaret.classification import *

# %%
df = pd.read_feather('credit_scoring.ftr')

# %% [markdown]
# ## Amostragem
#
# Separe os três últimos meses como safras de validação *out of time* (oot).
#
# Variáveis:<br>
# Considere que a variável ```data_ref``` não é uma variável explicativa, é somente uma variável indicadora da safra, e não deve ser utilizada na modelagem. A variávei ```index``` é um identificador do cliente, e também não deve ser utilizada como covariável (variável explicativa). As restantes podem ser utilizadas para prever a inadimplência, incluindo a renda.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 750000 entries, 0 to 749999
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   data_ref               750000 non-null  datetime64[ns]
#  1   index                  750000 non-null  int64
#  2   sexo                   750000 non-null  object
#  3   posse_de_veiculo       750000 non-null  object
#  4   posse_de_imovel        750000 non-null  object
#  5   qtd_filhos             750000 non-null  int64
#  6   tipo_renda             750000 non-null  object
#  7   educacao               750000 non-null  object
#  8   estado_civil           750000 non-null  object
#  9   tipo_residencia        750000 non-null  object
#  10  idade                  750000 non-null  int64
#  11  tempo_emprego          624043 non-null  float64
#  12  qt_pessoas_residencia  750000 non-null  float64
#  13  renda                  750000 non-null  float64
#  14  mau                    750000 non-null  bool
# dtypes: bool(1), datetime64[ns](1), float64(3), int64(3), object(7)
# memory usage: 80.8+ MB

# %%
#data_ref
print(df.data_ref.min())
print(df.data_ref.max())
# Out:
# 2015-01-01 00:00:00
# 2016-03-01 00:00:00

# %%
#treino e teste
df.set_index('data_ref', inplace=True)

df_train = df['2015-01-01':'2015-12-01']
df_test = df['2016-01-01':]

df_train.reset_index(inplace=True)
df_test.reset_index(inplace=True)

df_train['mes'] = df_train['data_ref'].dt.month

# %% [markdown]
# ## Descritiva básica univariada
#
# - Descreva a base quanto ao número de linhas, número de linhas para cada mês em ```data_ref```.
# - Faça uma descritiva básica univariada de cada variável. Considere as naturezas diferentes: qualitativas e quantitativas.

# %%
fig, ax = plt.subplots(figsize=(13, 7))
sns.countplot(data=df_train, x='mes', palette='viridis', ax=ax)
ax.set_title('Número de linhas para cada mês da base de treino')
# Out:
# Text(0.5, 1.0, 'Número de linhas para cada mês da base de treino')

# %%
fig, ax = plt.subplots(nrows=4, ncols=2, figsize=(17, 28.9))

sns.countplot(data=df_train, x='sexo', palette='viridis', ax=ax[0, 0])
ax[0, 0].set_title('Quantidade de clientes do sexo feminino e masculino')

sns.countplot(data=df_train, x='posse_de_veiculo', palette='viridis', ax=ax[0, 1])
ax[0, 1].set_title('Quantidade de clientes que possuem e não possuem veículo')

sns.countplot(data=df_train, x='posse_de_imovel', palette='viridis', ax=ax[1, 0])
ax[1, 0].set_title('Quantidade de clientes que possuem e não possuem imóvel')

sns.countplot(data=df_train, x='mau', palette='viridis', ax=ax[1, 1])
ax[1, 1].set_title('Quantidade de clientes que são e não são mau pagadores')

sns.countplot(data=df_train, x='tipo_renda', palette='viridis', ax=ax[2, 0])
ax[2, 0].set_title('Quantidade de clientes por tipo de renda')

sns.countplot(data=df_train, x='educacao', palette='viridis', ax=ax[2, 1])
ax[2, 1].set_title('Quantidade de clientes por educação')
for tick in ax[2, 1].get_xticklabels():
    tick.set_rotation(15)

sns.countplot(data=df_train, x='estado_civil', palette='viridis', ax=ax[3, 0])
ax[3, 0].set_title('Quantidade de clientes por estado civil')

sns.countplot(data=df_train, x='tipo_residencia', palette='viridis', ax=ax[3, 1])
ax[3, 1].set_title('Quantidade de clientes por tipo de residência')
for tick in ax[3, 1].get_xticklabels():
    tick.set_rotation(15)

# %%
fig, ax = plt.subplots(nrows=5, ncols=1, figsize=(12.9, 24))

sns.countplot(data=df_train, x='qtd_filhos', palette='viridis', ax=ax[0])
ax[0].set_title('Quantidade de clientes por quantidade de filhos')

sns.countplot(data=df_train, x='qt_pessoas_residencia', palette='viridis', ax=ax[1])
ax[1].set_title('Quantidade de clientes por quantidade de pessoas na residência')

sns.countplot(data=df_train, x='idade', palette='viridis', ax=ax[2])
ax[2].set_title('Quantidade de clientes por idade')

sns.histplot(data=df_train, x='tempo_emprego', palette='dark', bins=50, ax=ax[3])
ax[3].set_title('Quantidade de clientes por tempo de emprego')

sns.histplot(data=df_train, x='renda', palette='dark', bins=50, ax=ax[4])
ax[4].set_title('Quantidade de clientes por renda')
# Out:
# Text(0.5, 1.0, 'Quantidade de clientes por renda')

# %%
fig, ax = plt.subplots(figsize=(10,5))

sns.histplot(data=df_train[df_train.renda<50000], x='renda', palette='dark', bins=50, ax=ax)
ax.set_title('Quantidade de clientes por renda menor que R$50.000,00')
# Out:
# Text(0.5, 1.0, 'Quantidade de clientes por renda menor que R$50.000,00')

# %%
fig, ax = plt.subplots(figsize=(10,5))

sns.histplot(data=df_train[df_train.renda>500000], x='renda', palette='dark', bins=50, ax=ax)
ax.set_title('Quantidade de clientes por renda maior que R$50.000,00 reais')
# Out:
# Text(0.5, 1.0, 'Quantidade de clientes por renda maior que R$50.000,00 reais')

# %% [markdown]
# ## Descritiva bivariada
#
# Faça uma análise descritiva bivariada de cada variável

# %%
fig, ax = plt.subplots(figsize=(13,7))
sns.lineplot(data=df_train, x='mes', y='mau', palette='viridis', ax=ax, marker='o')
ax.set_title('Proporção de mau para cada mês da base de treino')
ax.set_ylabel("Proporção de inadimplentes")
# Out:
# Text(0, 0.5, 'Proporção de inadimplentes')

# %%
# %%time
fig, ax = plt.subplots(nrows=4, ncols=2, figsize=(17, 28.9))

sns.lineplot(data=df_train, x='sexo', y='mau', palette='viridis', ax=ax[0, 0], marker='o')
ax[0, 0].set_title('Proporção de mau para sexo feminino e masculino')
ax[0, 0].set_ylabel("Proporção de inadimplentes")

sns.lineplot(data=df_train, x='posse_de_veiculo', y='mau', palette='viridis', ax=ax[0, 1], marker='o')
ax[0, 1].set_title('Proporção de mau para clientes que possuem e não possuem veículo')
ax[0, 1].set_ylabel("Proporção de inadimplentes")

sns.lineplot(data=df_train, x='posse_de_imovel', y='mau', palette='viridis', ax=ax[1, 0], marker='o')
ax[1, 0].set_title('Proporção de mau para clientes que possuem e não possuem imóvel')
ax[1, 0].set_ylabel("Proporção de inadimplentes")

ax[1, 1].axis('off')

sns.lineplot(data=df_train, x='tipo_renda', y='mau', palette='viridis', ax=ax[2, 0], marker='o')
ax[2, 0].set_title('Proporção de mau por tipo de renda')
ax[2, 0].set_ylabel("Proporção de inadimplentes")

sns.lineplot(data=df_train, x='educacao', y='mau', palette='viridis', ax=ax[2, 1], marker='o')
ax[2, 1].set_title('Proporção de mau por educação')
ax[2, 1].set_ylabel("Proporção de inadimplentes")
for tick in ax[2, 1].get_xticklabels():
    tick.set_rotation(7)

sns.lineplot(data=df_train, x='estado_civil', y='mau', palette='viridis', ax=ax[3, 0], marker='o')
ax[3, 0].set_title('Proporção de mau por estado civil')
ax[3, 0].set_ylabel("Proporção de inadimplentes")

sns.lineplot(data=df_train, x='tipo_residencia', y='mau', palette='viridis', ax=ax[3, 1], marker='o')
ax[3, 1].set_title('Proporção de mau por tipo de residência')
ax[3, 1].set_ylabel("Proporção de inadimplentes")
for tick in ax[3, 1].get_xticklabels():
    tick.set_rotation(7)
# Out:
# CPU times: total: 35.3 s
# Wall time: 36.5 s

# %%
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(15, 10))

sns.lineplot(data=df_train, x='qtd_filhos', y='mau', palette='viridis', ax=ax[0], marker='o')
ax[0].set_title('Proporção de mau por quantidade de filhos')
ax[0].set_ylabel("Proporção de inadimplentes")

sns.lineplot(data=df_train, x='qt_pessoas_residencia', y='mau', palette='viridis', ax=ax[1], marker='o')
ax[1].set_title('Proporção de mau por quantidade de pessoas na residência')
ax[1].set_ylabel("Proporção de inadimplentes")
# Out:
# Text(0, 0.5, 'Proporção de inadimplentes')

# %%
fig, ax = plt.subplots(figsize=(13, 7))

cat_1, bins = pd.qcut(df_train['idade'], 15, retbins=True)
df_1 = df_train.groupby(cat_1)
biv = df_1['mau'].mean()

ax = biv.plot.line(marker='o')
ax.set_ylabel("Proporção de inadimplentes")
ticks = plt.xticks(range(len(biv.index.values)), biv.index.values, rotation=90)
ax.set_title('Proporção de mau para intervalos de idade')
# Out:
# Text(0.5, 1.0, 'Proporção de mau para intervalos de idade')

# %%
fig, ax = plt.subplots(figsize=(13, 7))

cat_1, bins = pd.qcut(df_train['renda'], 15, retbins=True)
df_1 = df_train.groupby(cat_1)
biv = df_1['mau'].mean()

ax = biv.plot.line(marker='o')
ax.set_ylabel("Proporção de inadimplentes")
ticks = plt.xticks(range(len(biv.index.values)), biv.index.values, rotation=90)
ax.set_title('Proporção de mau para intervalos de renda')
# Out:
# Text(0.5, 1.0, 'Proporção de mau para intervalos de renda')

# %% [markdown]
# ## Desenvolvimento do modelo
#
# Desenvolva um modelo de *credit scoring* através de uma regressão logística.
#
# - Trate valores missings e outliers
# - Trate 'zeros estruturais'
# - Faça agrupamentos de categorias conforme vimos em aula
# - Proponha uma equação preditiva para 'mau'
# - Caso hajam categorias não significantes, justifique

# %%
def IV(variavel, resposta):
    tab = pd.crosstab(variavel, resposta, margins=True, margins_name='total')

    tilo_evento = tab.columns[0]
    tilo_nao_evento = tab.columns[1]

    tab['pct_evento'] = tab[tilo_evento]/tab.loc['total', tilo_evento]
    tab['ep'] = tab[tilo_evento]/tab.loc['total', tilo_evento]

    tab['pct_nao_evento'] = tab[tilo_nao_evento] / tab.loc['total', tilo_nao_evento]
    tab['woe'] = np.log(tab.pct_evento/tab.pct_nao_evento)
    tab['iv_parcial'] = (tab.pct_evento - tab.pct_nao_evento)*tab.woe
    return tab['iv_parcial'].sum()

# %%
def biv_discreta(var, df):
    df['bom'] = 1-df.mau
    g = df.groupby(var)

    biv = pd.DataFrame({'qt_bom': g['bom'].sum(),
                        'qt_mau': g['mau'].sum(),
                        'mau': g['mau'].mean(),
                        var: g['mau'].mean().index,
                        'cont': g[var].count()})

    biv['ep'] = (biv.mau*(1-biv.mau)/biv.cont)**.5
    biv['mau_sup'] = biv.mau+t.ppf([0.975], biv.cont-1)*biv.ep
    biv['mau_inf'] = biv.mau+t.ppf([0.025], biv.cont-1)*biv.ep

    biv['logit'] = np.log(biv.mau/(1-biv.mau))
    biv['logit_sup'] = np.log(biv.mau_sup/(1-biv.mau_sup))
    biv['logit_inf'] = np.log(biv.mau_inf/(1-biv.mau_inf))

    tx_mau_geral = df.mau.mean()
    woe_geral = np.log(df.mau.mean() / (1 - df.mau.mean()))

    biv['woe'] = biv.logit - woe_geral
    biv['woe_sup'] = biv.logit_sup - woe_geral
    biv['woe_inf'] = biv.logit_inf - woe_geral

    fig, ax = plt.subplots(2, 1, figsize=(8, 6))
    ax[0].plot(biv[var], biv.woe, ':bo', label='woe')
    ax[0].plot(biv[var], biv.woe_sup, 'o:r', label='limite superior')
    ax[0].plot(biv[var], biv.woe_inf, 'o:r', label='limite inferior')

    num_cat = biv.shape[0]
    ax[0].set_xlim([-.3, num_cat-.7])

    ax[0].set_ylabel("Weight of Evidence")
    ax[0].legend(bbox_to_anchor=(.83, 1.17), ncol=3)

    ax[0].set_xticks(list(range(num_cat)))
    ax[0].set_xticklabels(biv[var], rotation=8)

    ax[1] = biv.cont.plot.bar()
    return biv

# %%
def biv_continua(var, ncat, df):
    df['bom'] = 1-df.mau
    cat_srs, bins = pd.qcut(df[var], ncat, retbins=True, precision=0, duplicates='drop')
    g = df.groupby(cat_srs)

    biv = pd.DataFrame({'qt_bom': g['bom'].sum(),
                        'qt_mau': g['mau'].sum(),
                        'mau': g['mau'].mean(),
                        var: g[var].mean(),
                        'cont': g[var].count()})

    biv['ep'] = (biv.mau*(1-biv.mau)/biv.cont)**.5
    biv['mau_sup'] = biv.mau+t.ppf([0.975], biv.cont-1)*biv.ep
    biv['mau_inf'] = biv.mau+t.ppf([0.025], biv.cont-1)*biv.ep

    biv['logit'] = np.log(biv.mau/(1-biv.mau))
    biv['logit_sup'] = np.log(biv.mau_sup/(1-biv.mau_sup))
    biv['logit_inf'] = np.log(biv.mau_inf/(1-biv.mau_inf))

    tx_mau_geral = df.mau.mean()
    woe_geral = np.log(df.mau.mean() / (1 - df.mau.mean()))

    biv['woe'] = biv.logit - woe_geral
    biv['woe_sup'] = biv.logit_sup - woe_geral
    biv['woe_inf'] = biv.logit_inf - woe_geral

    fig, ax = plt.subplots(2, 1, figsize=(8, 6))
    ax[0].plot(biv[var], biv.woe, ':bo', label='woe')
    ax[0].plot(biv[var], biv.woe_sup, 'o:r', label='limite superior')
    ax[0].plot(biv[var], biv.woe_inf, 'o:r', label='limite inferior')

    num_cat = biv.shape[0]

    ax[0].set_ylabel("Weight of Evidence")
    ax[0].legend(bbox_to_anchor=(.83, 1.17), ncol=3)

    ax[1] = biv.cont.plot.bar()
    return None

# %%
df_train['mau'] = df_train.mau.astype('int64')
df_train.drop(columns=['data_ref', 'index', 'mes'], inplace=True)
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600000 entries, 0 to 599999
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   sexo                   600000 non-null  object
#  1   posse_de_veiculo       600000 non-null  object
#  2   posse_de_imovel        600000 non-null  object
#  3   qtd_filhos             600000 non-null  int64
#  4   tipo_renda             600000 non-null  object
#  5   educacao               600000 non-null  object
#  6   estado_civil           600000 non-null  object
#  7   tipo_residencia        600000 non-null  object
#  8   idade                  600000 non-null  int64
#  9   tempo_emprego          499125 non-null  float64
#  10  qt_pessoas_residencia  600000 non-null  float64
#  11  renda                  600000 non-null  float64
#  12  mau                    600000 non-null  int64
# dtypes: float64(3), int64(3), object(7)
# memory usage: 59.5+ MB

# %%
#tratamento missing
df_train['tempo_emprego'].fillna(value=df_train['tempo_emprego'].mean(), inplace=True)

# %%
metadados = pd.DataFrame(df_train.dtypes, columns=['dtype'])
metadados['nmissing'] = df_train.isna().sum()
metadados['valores_unicos'] = df_train.nunique()
metadados['papel'] = 'covariavel'
metadados.loc['mau', 'papel'] = 'resposta'
metadados
# Out:
#                          dtype  nmissing  valores_unicos       papel
# sexo                    object         0               2  covariavel
# posse_de_veiculo        object         0               2  covariavel
# posse_de_imovel         object         0               2  covariavel
# qtd_filhos               int64         0               8  covariavel
# tipo_renda              object         0               5  covariavel
# educacao                object         0               5  covariavel
# estado_civil            object         0               5  covariavel
# tipo_residencia         object         0               6  covariavel
# idade                    int64         0              47  covariavel
# tempo_emprego          float64         0            3005  covariavel
# qt_pessoas_residencia  float64         0               9  covariavel
# renda                  float64         0          112472  covariavel
# mau                      int64         0               2    resposta

# %%
for var in metadados[metadados.papel == 'covariavel'].index:
    if (metadados.loc[var, 'valores_unicos'] > 10):
        metadados.loc[var, 'IV'] = IV(pd.qcut(df_train[var], 5, duplicates='drop'), df_train.mau)
    else:
        metadados.loc[var, 'IV'] = IV(df_train[var], df_train.mau)

metadados
# Out:
#                          dtype  nmissing  valores_unicos       papel        IV
# sexo                    object         0               2  covariavel  0.002665
# posse_de_veiculo        object         0               2  covariavel  0.000075
# posse_de_imovel         object         0               2  covariavel  0.009690
# qtd_filhos               int64         0               8  covariavel  0.001689
# tipo_renda              object         0               5  covariavel  0.009718
# educacao                object         0               5  covariavel  0.003690
# estado_civil            object         0               5  covariavel  0.001305
# tipo_residencia         object         0               6  covariavel  0.003330
# idade                    int64         0              47  covariavel  0.018434
# tempo_emprego          float64         0            3005  covariavel  0.283956
# qt_pessoas_residencia  float64         0               9  covariavel       inf
# renda                  float64         0          112472  covariavel  0.959826
# mau                      int64         0               2    resposta       NaN

# %%
biv_discreta('sexo', df_train)
# Out:
#       qt_bom  qt_mau       mau sexo    cont        ep   mau_sup   mau_inf  \
# sexo
# F     378318   25487  0.063117    F  403805  0.000383  0.063867  0.062367
# M     185039   11156  0.056862    M  196195  0.000523  0.057887  0.055837
#
#          logit  logit_sup  logit_inf       woe   woe_sup  woe_inf
# sexo
# F    -2.697567  -2.684953  -2.710321  0.035125  0.047739  0.02237
# M    -2.808589  -2.789641  -2.827861 -0.075898 -0.056950 -0.09517

# %%
biv_discreta('posse_de_veiculo', df_train)
# Out:
#                   qt_bom  qt_mau       mau posse_de_veiculo    cont        ep  \
# posse_de_veiculo
# N                 343778   22515  0.061467                N  366293  0.000397
# S                 219579   14128  0.060452                S  233707  0.000493
#
#                    mau_sup   mau_inf     logit  logit_sup  logit_inf  \
# posse_de_veiculo
# N                 0.062245  0.060689 -2.725814  -2.712410  -2.739378
# S                 0.061418  0.059486 -2.743553  -2.726667  -2.760694
#
#                        woe   woe_sup   woe_inf
# posse_de_veiculo
# N                 0.006877  0.020281 -0.006687
# S                -0.010862  0.006024 -0.028003

# %%
biv_discreta('posse_de_imovel', df_train)
# Out:
#                  qt_bom  qt_mau       mau posse_de_imovel    cont        ep  \
# posse_de_imovel
# N                183305   13641  0.069263               N  196946  0.000572
# S                380052   23002  0.057069               S  403054  0.000365
#
#                   mau_sup   mau_inf     logit  logit_sup  logit_inf       woe  \
# posse_de_imovel
# N                0.070384  0.068141 -2.598071  -2.580806  -2.615598  0.134620
# S                0.057785  0.056353 -2.804727  -2.791496  -2.818114 -0.072036
#
#                   woe_sup   woe_inf
# posse_de_imovel
# N                0.151885  0.117093
# S               -0.058805 -0.085423

# %%
biv_discreta('qtd_filhos', df_train)
# Out:
#             qt_bom  qt_mau       mau  qtd_filhos    cont        ep   mau_sup  \
# qtd_filhos
# 0           389129   24753  0.059807           0  413882  0.000369  0.060529
# 1           114547    7924  0.064701           1  122471  0.000703  0.066079
# 2            52182    3421  0.061525           2   55603  0.001019  0.063523
# 3             6493     467  0.067098           3    6960  0.002999  0.072977
# 4              806      48  0.056206           4     854  0.007881  0.071675
# 5               67      10  0.129870           5      77  0.038309  0.206169
# 7               69      13  0.158537           7      82  0.040334  0.238789
# 14              64       7  0.098592          14      71  0.035379  0.169154
#
#              mau_inf     logit  logit_sup  logit_inf       woe   woe_sup  \
# qtd_filhos
# 0           0.059084 -2.754964  -2.742189  -2.767885 -0.022273 -0.009497
# 1           0.063323 -2.671089  -2.648545  -2.694085  0.061602  0.084147
# 2           0.059528 -2.724805  -2.690727  -2.759933  0.007886  0.041964
# 3           0.061219 -2.632151  -2.541841  -2.730127  0.100540  0.190850
# 4           0.040737 -2.820883  -2.561236  -3.159030 -0.088192  0.171455
# 5           0.053571 -1.902108  -1.348173  -2.871687  0.830584  1.384518
# 7           0.078284 -1.669157  -1.159328  -2.465897  1.063534  1.573363
# 14          0.028029 -2.212973  -1.591637  -3.546072  0.519718  1.141054
#
#              woe_inf
# qtd_filhos
# 0          -0.035194
# 1           0.038606
# 2          -0.027241
# 3           0.002564
# 4          -0.426339
# 5          -0.138996
# 7           0.266795
# 14         -0.813381

# %%
biv_discreta('tipo_renda', df_train)
# Out:
#                   qt_bom  qt_mau       mau        tipo_renda    cont  \
# tipo_renda
# Assalariado       288865   19595  0.063525       Assalariado  308460
# Bolsista             279      12  0.041237          Bolsista     291
# Empresário        129935    8206  0.059403        Empresário  138141
# Pensionista        94627    6500  0.064276       Pensionista  101127
# Servidor público   49651    2330  0.044824  Servidor público   51981
#
#                         ep   mau_sup   mau_inf     logit  logit_sup  \
# tipo_renda
# Assalariado       0.000439  0.064386  0.062665 -2.690685  -2.676307
# Bolsista          0.011656  0.064178  0.018296 -3.146305  -2.679758
# Empresário        0.000636  0.060650  0.058157 -2.762169  -2.740076
# Pensionista       0.000771  0.065787  0.062764 -2.678141  -2.653280
# Servidor público  0.000908  0.046603  0.043045 -3.059150  -3.018369
#
#                   logit_inf       woe   woe_sup   woe_inf
# tipo_renda
# Assalariado       -2.705246  0.042006  0.056384  0.027445
# Bolsista          -3.982616 -0.413614  0.052933 -1.249925
# Empresário        -2.784700 -0.029478 -0.007385 -0.052009
# Pensionista       -2.703552  0.054550  0.079411  0.029139
# Servidor público  -3.101504 -0.326459 -0.285678 -0.368813

# %%
# Agrupando as classes da variável educacao

df_train.tipo_renda.replace(
    {'Assalariado': 'Assalariado/Bolsista',
     'Bolsista': 'Assalariado/Bolsista'}, inplace=True)

biv_discreta('tipo_renda', df_train)
IV(df_train.tipo_renda, df_train.mau)
# Out:
# 0.009634301334170859

# %%
biv_discreta('educacao', df_train)
# Out:
#                      qt_bom  qt_mau       mau             educacao    cont  \
# educacao
# Fundamental            6420     481  0.069700          Fundamental    6901
# Médio                379939   25510  0.062918                Médio  405449
# Pós graduação           608      43  0.066052        Pós graduação     651
# Superior completo    154354    9086  0.055592    Superior completo  163440
# Superior incompleto   22036    1523  0.064646  Superior incompleto   23559
#
#                            ep   mau_sup   mau_inf     logit  logit_sup  \
# educacao
# Fundamental          0.003065  0.075709  0.063691 -2.591306  -2.502130
# Médio                0.000381  0.063665  0.062170 -2.700940  -2.688333
# Pós graduação        0.009735  0.085167  0.046937 -2.648975  -2.374126
# Superior completo    0.000567  0.056703  0.054481 -2.832514  -2.811552
# Superior incompleto  0.001602  0.067786  0.061506 -2.671995  -2.621201
#
#                      logit_inf       woe   woe_sup   woe_inf
# educacao
# Fundamental          -2.687900  0.141385  0.230561  0.044791
# Médio                -2.713688  0.031751  0.044358  0.019003
# Pós graduação        -3.010867  0.083716  0.358565 -0.278176
# Superior completo    -2.853874 -0.099823 -0.078861 -0.121183
# Superior incompleto  -2.725141  0.060696  0.111490  0.007550

# %%
# Agrupando as classes da variável educacao

df_train.educacao.replace(
    {'Fundamental': 'Fund/Médio/Sup Incomp',
     'Médio': 'Fund/Médio/Sup Incomp',
     'Superior incompleto': 'Fund/Médio/Sup Incomp',
     'Superior completo': 'Sup Comp/Pós',
     'Pós graduação': 'Sup Comp/Pós'}, inplace=True)

biv_discreta('educacao', df_train)
IV(df_train.educacao, df_train.mau)
# Out:
# 0.0034801108923340892

# %%
biv_discreta('estado_civil', df_train)
# Out:
#               qt_bom  qt_mau       mau estado_civil    cont        ep  \
# estado_civil
# Casado        395880   25269  0.060000       Casado  421149  0.000366
# Separado       31994    2194  0.064175     Separado   34188  0.001325
# Solteiro       68585    4636  0.063315     Solteiro   73221  0.000900
# União          43048    3060  0.066366        União   46108  0.001159
# Viúvo          23850    1484  0.058577        Viúvo   25334  0.001475
#
#                mau_sup   mau_inf     logit  logit_sup  logit_inf       woe  \
# estado_civil
# Casado        0.060717  0.059283 -2.751533  -2.738886  -2.764322 -0.018842
# Separado      0.066772  0.061577 -2.679822  -2.637360  -2.723916  0.052869
# Solteiro      0.065079  0.061551 -2.694222  -2.664858  -2.724359  0.038469
# União         0.068638  0.064094 -2.643901  -2.607801  -2.681168  0.088790
# Viúvo         0.061469  0.055686 -2.777043  -2.725779  -2.830738 -0.044352
#
#                woe_sup   woe_inf
# estado_civil
# Casado       -0.006195 -0.031631
# Separado      0.095331  0.008775
# Solteiro      0.067833  0.008332
# União         0.124890  0.051523
# Viúvo         0.006912 -0.098047

# %%
biv_discreta('tipo_residencia', df_train)
# Out:
#                  qt_bom  qt_mau       mau tipo_residencia    cont        ep  \
# tipo_residencia
# Aluguel            7666     596  0.072137         Aluguel    8262  0.002846
# Casa             506887   32449  0.060165            Casa  539336  0.000324
# Com os pais       24733    1997  0.074710     Com os pais   26730  0.001608
# Comunitário        2449     185  0.070235     Comunitário    2634  0.004979
# Estúdio            4071     225  0.052374         Estúdio    4296  0.003399
# Governamental     17551    1191  0.063547   Governamental   18742  0.001782
#
#                   mau_sup   mau_inf     logit  logit_sup  logit_inf       woe  \
# tipo_residencia
# Aluguel          0.077717  0.066558 -2.554310  -2.473779  -2.640804  0.178382
# Casa             0.060799  0.059530 -2.748618  -2.737450  -2.759898 -0.015927
# Com os pais      0.077862  0.071558 -2.516492  -2.471755  -2.563000  0.216199
# Comunitário      0.079999  0.060472 -2.583079  -2.442363  -2.743199  0.149612
# Estúdio          0.059038  0.045711 -2.895544  -2.768721  -3.038637 -0.162852
# Governamental    0.067040  0.060054 -2.690318  -2.633076  -2.750571  0.042373
#
#                   woe_sup   woe_inf
# tipo_residencia
# Aluguel          0.258912  0.091887
# Casa            -0.004759 -0.027207
# Com os pais      0.260936  0.169691
# Comunitário      0.290329 -0.010508
# Estúdio         -0.036030 -0.305946
# Governamental    0.099615 -0.017880

# %%
biv_discreta('qt_pessoas_residencia', df_train)
# Out:
#                        qt_bom  qt_mau       mau  qt_pessoas_residencia  \
# qt_pessoas_residencia
# 1.0                    101834    6823  0.062794                    1.0
# 2.0                    306954   19227  0.058946                    2.0
# 3.0                     97323    6803  0.065334                    3.0
# 4.0                     50051    3263  0.061203                    4.0
# 5.0                      6189     449  0.067641                    5.0
# 6.0                       832      58  0.065169                    6.0
# 7.0                        41       0  0.000000                    7.0
# 9.0                        69      13  0.158537                    9.0
# 15.0                       64       7  0.098592                   15.0
#
#                          cont        ep   mau_sup   mau_inf     logit  \
# qt_pessoas_residencia
# 1.0                    108657  0.000736  0.064236  0.061351 -2.703045
# 2.0                    326181  0.000412  0.059754  0.058138 -2.770382
# 3.0                    104126  0.000766  0.066835  0.063833 -2.660672
# 4.0                     53314  0.001038  0.063238  0.059169 -2.730395
# 5.0                      6638  0.003082  0.073683  0.061599 -2.623506
# 6.0                       890  0.008274  0.081406  0.048931 -2.663389
# 7.0                        41  0.000000  0.000000  0.000000      -inf
# 9.0                        82  0.040334  0.238789  0.078284 -1.669157
# 15.0                       71  0.035379  0.169154  0.028029 -2.212973
#
#                        logit_sup  logit_inf       woe   woe_sup   woe_inf
# qt_pessoas_residencia
# 1.0                    -2.678793  -2.727822  0.029646  0.053898  0.004869
# 2.0                    -2.755904  -2.785048 -0.037691 -0.023213 -0.052357
# 3.0                    -2.636351  -2.685518  0.072019  0.096340  0.047173
# 4.0                    -2.695521  -2.766371  0.002296  0.037170 -0.033680
# 5.0                    -2.531442  -2.723540  0.109185  0.201250  0.009151
# 6.0                    -2.423389  -2.967184  0.069302  0.309302 -0.234493
# 7.0                         -inf       -inf      -inf      -inf      -inf
# 9.0                    -1.159328  -2.465897  1.063534  1.573363  0.266795
# 15.0                   -1.591637  -3.546072  0.519718  1.141054 -0.813381

# %%
# Zeros Estruturais
biv_continua('idade', 5, df_train)

# %%
biv_continua('tempo_emprego', 15, df_train)

# %%
biv_continua('renda', 15, df_train)

# %%
' + '.join(list(metadados.sort_values(by='IV', ascending=False).index))
# Out:
# 'qt_pessoas_residencia + renda + tempo_emprego + idade + tipo_renda + posse_de_imovel + educacao + tipo_residencia + sexo + qtd_filhos + estado_civil + posse_de_veiculo + mau'

# %%
formula = '''
    mau ~ sexo + posse_de_veiculo + posse_de_imovel + qtd_filhos + tipo_renda +
    educacao + estado_civil + tipo_residencia + idade + tempo_emprego +
    renda
'''

rl = smf.glm(formula, data=df_train, family=sm.families.Binomial()).fit()

rl.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                    mau   No. Observations:               600000
# Model:                            GLM   Df Residuals:                   599979
# Model Family:                Binomial   Df Model:                           20
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:            -1.2488e+05
# Date:                Wed, 21 Feb 2024   Deviance:                   2.4965e+05
# Time:                        13:45:11   Pearson chi2:                 1.57e+16
# No. Iterations:                    11   Pseudo R-squ. (CS):            0.04260
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                           -1.4189      0.053    -26.825      0.000      -1.523      -1.315
# sexo[T.M]                           -0.1255      0.013     -9.567      0.000      -0.151      -0.100
# posse_de_veiculo[T.S]                0.0313      0.012      2.529      0.011       0.007       0.056
# posse_de_imovel[T.S]                -0.0847      0.012     -7.178      0.000      -0.108      -0.062
# tipo_renda[T.Empresário]            -0.0545      0.014     -3.900      0.000      -0.082      -0.027
# tipo_renda[T.Pensionista]           -0.0411      0.020     -2.032      0.042      -0.081      -0.001
# tipo_renda[T.Servidor público]      -0.0330      0.023     -1.421      0.155      -0.079       0.013
# educacao[T.Sup Comp/Pós]            -0.0566      0.013     -4.326      0.000      -0.082      -0.031
# estado_civil[T.Separado]             0.0374      0.024      1.574      0.116      -0.009       0.084
# estado_civil[T.Solteiro]             0.0054      0.017      0.311      0.756      -0.029       0.039
# estado_civil[T.União]                0.0472      0.020      2.322      0.020       0.007       0.087
# estado_civil[T.Viúvo]               -0.0346      0.029     -1.192      0.233      -0.092       0.022
# tipo_residencia[T.Casa]             -0.0879      0.044     -1.995      0.046      -0.174      -0.002
# tipo_residencia[T.Com os pais]      -0.0731      0.050     -1.475      0.140      -0.170       0.024
# tipo_residencia[T.Comunitário]      -0.1403      0.089     -1.572      0.116      -0.315       0.035
# tipo_residencia[T.Estúdio]          -0.0327      0.082     -0.397      0.691      -0.194       0.129
# tipo_residencia[T.Governamental]    -0.0834      0.053     -1.565      0.118      -0.188       0.021
# qtd_filhos                           0.0036      0.008      0.448      0.654      -0.012       0.019
# idade                                0.0003      0.001      0.394      0.693      -0.001       0.002
# tempo_emprego                       -0.0236      0.002    -13.100      0.000      -0.027      -0.020
# renda                               -0.0001   1.09e-06    -93.691      0.000      -0.000   -9.96e-05
# ====================================================================================================
# """

# %%
formula = '''
    mau ~ sexo + posse_de_imovel + educacao +
    tempo_emprego + renda
'''

rl = smf.glm(formula, data=df_train, family=sm.families.Binomial()).fit()

rl.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                    mau   No. Observations:               600000
# Model:                            GLM   Df Residuals:                   599994
# Model Family:                Binomial   Df Model:                            5
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:            -1.2490e+05
# Date:                Wed, 21 Feb 2024   Deviance:                   2.4969e+05
# Time:                        13:45:18   Pearson chi2:                 1.59e+16
# No. Iterations:                    11   Pseudo R-squ. (CS):            0.04253
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                   -1.4931      0.014   -107.439      0.000      -1.520      -1.466
# sexo[T.M]                   -0.1072      0.012     -8.926      0.000      -0.131      -0.084
# posse_de_imovel[T.S]        -0.0897      0.011     -7.845      0.000      -0.112      -0.067
# educacao[T.Sup Comp/Pós]    -0.0569      0.013     -4.477      0.000      -0.082      -0.032
# tempo_emprego               -0.0245      0.002    -14.616      0.000      -0.028      -0.021
# renda                       -0.0001   1.08e-06    -94.209      0.000      -0.000   -9.96e-05
# ============================================================================================
# """

# %%
formula = '''
    mau ~ sexo + posse_de_imovel + educacao +
    tempo_emprego + renda
'''

rl = smf.glm(formula, data=df_train, family=sm.families.Binomial()).fit()

rl.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                    mau   No. Observations:               600000
# Model:                            GLM   Df Residuals:                   599994
# Model Family:                Binomial   Df Model:                            5
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:            -1.2490e+05
# Date:                Wed, 21 Feb 2024   Deviance:                   2.4969e+05
# Time:                        13:45:26   Pearson chi2:                 1.59e+16
# No. Iterations:                    11   Pseudo R-squ. (CS):            0.04253
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                   -1.4931      0.014   -107.439      0.000      -1.520      -1.466
# sexo[T.M]                   -0.1072      0.012     -8.926      0.000      -0.131      -0.084
# posse_de_imovel[T.S]        -0.0897      0.011     -7.845      0.000      -0.112      -0.067
# educacao[T.Sup Comp/Pós]    -0.0569      0.013     -4.477      0.000      -0.082      -0.032
# tempo_emprego               -0.0245      0.002    -14.616      0.000      -0.028      -0.021
# renda                       -0.0001   1.08e-06    -94.209      0.000      -0.000   -9.96e-05
# ============================================================================================
# """

# %%
formula = '''
    mau ~ sexo + posse_de_imovel + educacao +
    tempo_emprego + np.log(renda)
'''

rl = smf.glm(formula, data=df_train, family=sm.families.Binomial()).fit()

rl.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                    mau   No. Observations:               600000
# Model:                            GLM   Df Residuals:                   599994
# Model Family:                Binomial   Df Model:                            5
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:            -1.2027e+05
# Date:                Wed, 21 Feb 2024   Deviance:                   2.4055e+05
# Time:                        13:45:34   Pearson chi2:                 5.97e+05
# No. Iterations:                     7   Pseudo R-squ. (CS):            0.05720
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                    5.9194      0.051    115.829      0.000       5.819       6.020
# sexo[T.M]                   -0.0018      0.012     -0.149      0.882      -0.026       0.022
# posse_de_imovel[T.S]        -0.0175      0.012     -1.494      0.135      -0.040       0.005
# educacao[T.Sup Comp/Pós]    -0.0056      0.013     -0.430      0.667      -0.031       0.020
# tempo_emprego               -0.0010      0.002     -0.610      0.542      -0.004       0.002
# np.log(renda)               -0.9881      0.007   -149.914      0.000      -1.001      -0.975
# ============================================================================================
# """

# %%
formula = '''
    mau ~ np.log(renda)
'''

rl = smf.glm(formula, data=df_train, family=sm.families.Binomial()).fit()

rl.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                    mau   No. Observations:               600000
# Model:                            GLM   Df Residuals:                   599998
# Model Family:                Binomial   Df Model:                            1
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:            -1.2028e+05
# Date:                Wed, 21 Feb 2024   Deviance:                   2.4055e+05
# Time:                        13:45:36   Pearson chi2:                 5.97e+05
# No. Iterations:                     7   Pseudo R-squ. (CS):            0.05719
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         5.9239      0.049    121.382      0.000       5.828       6.020
# np.log(renda)    -0.9908      0.006   -169.858      0.000      -1.002      -0.979
# =================================================================================
# """

# %% [markdown]
# ## Avaliação do modelo
#
# Avalie o poder discriminante do modelo pelo menos avaliando acurácia, KS e Gini.
#
# Avalie estas métricas nas bases de desenvolvimento e *out of time*.

# %%
df_train['score'] = rl.predict(df_train)

# Acurácia
acc = metrics.accuracy_score(df_train.mau, df_train.score > .068)

# AUC
fpr, tpr, thresholds = metrics.roc_curve(df_train.mau, df_train.score)
auc = metrics.auc(fpr, tpr)

# Gini
gini = 2*auc - 1
ks = ks_2samp(df_train.loc[df_train.mau == 1, 'score'],
              df_train.loc[df_train.mau != 1, 'score']).statistic

print('Acurácia: {0:.1%} \nAUC: {1:.1%} \nGINI: {2:.1%}\nKS: {3:.1%}'.format(acc, auc, gini, ks))
# Out:
# Acurácia: 71.9%
# AUC: 77.0%
# GINI: 54.0%
# KS: 39.9%

# %%
fpr, tpr, thresholds = metrics.roc_curve(df_train['mau'], df_train['score'])

plt.figure()
lw = 2

fpr, tpr, thresholds = metrics.roc_curve(df_train['mau'], df_train['score'])
auc_ = metrics.auc(fpr, tpr)
plt.plot(fpr, tpr, color='darkorange', lw=lw, label='ROC curve (area = %0.2f)' % auc_)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC curve')
plt.legend(loc="lower right")
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

score_pop1 = df_train.loc[df_train['mau'] == 1, 'score']
ax.plot(np.sort(score_pop1), np.linspace(0, 1, len(score_pop1), endpoint=False), label='Mau')

score_pop2 = df_train.loc[df_train['mau'] != 1, 'score']
ax.plot(np.sort(score_pop2), np.linspace(0, 1, len(score_pop2), endpoint=False), label='Bom')
ax.legend()

ax.set_xlabel('P')

ax.set_ylabel('Função Distribuição Acumulada')
# Out:
# Text(0, 0.5, 'Função Distribuição Acumulada')

# %%
#Out of time
df_test['tempo_emprego'].fillna(value=df_test['tempo_emprego'].mean(), inplace=True)

# %%
df_test.educacao.replace(
    {'Fundamental': 'Fund/Médio/Sup Incomp',
     'Médio': 'Fund/Médio/Sup Incomp',
     'Superior incompleto': 'Fund/Médio/Sup Incomp',
     'Superior completo': 'Sup Comp/Pós',
     'Pós graduação': 'Sup Comp/Pós'}, inplace=True)

# %%
df_test['score'] = rl.predict(df_test)

# Acurácia
acc = metrics.accuracy_score(df_test.mau, df_test.score > .068)

# AUC
fpr, tpr, thresholds = metrics.roc_curve(df_test.mau, df_test.score)
auc = metrics.auc(fpr, tpr)

# Gini
gini = 2*auc - 1
ks = ks_2samp(df_test.loc[df_test.mau == 1, 'score'],
              df_test.loc[df_test.mau != 1, 'score']).statistic

print('Acurácia: {0:.1%} \nAUC: {1:.1%} \nGINI: {2:.1%}\nKS: {3:.1%}'.format(acc, auc, gini, ks))
# Out:
# Acurácia: 39.3%
# AUC: 73.9%
# GINI: 47.8%
# KS: 34.7%

# %%
fpr, tpr, thresholds = metrics.roc_curve(df_test['mau'], df_test['score'])

plt.figure()
lw = 2

fpr, tpr, thresholds = metrics.roc_curve(df_test['mau'], df_test['score'])
auc_ = metrics.auc(fpr, tpr)
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % auc_)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC curve')
plt.legend(loc="lower right")
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

score_pop1 = df_test.loc[df_test['mau'] == 1, 'score']
ax.plot(np.sort(score_pop1), np.linspace(0, 1, len(score_pop1), endpoint=False), label='Mau')

score_pop2 = df_test.loc[df_test['mau'] != 1, 'score']
ax.plot(np.sort(score_pop2), np.linspace(0, 1, len(score_pop2), endpoint=False), label='Bom')
ax.legend()

ax.set_xlabel('P')
ax.set_ylabel('Função Distribuição Acumulada')
# Out:
# Text(0, 0.5, 'Função Distribuição Acumulada')

# %% [markdown]
# Após a análise dos gráficos é possivel ver que a acurácia teve uma grande queda, os valores AUC, GINI e KS não tiveram

# %% [markdown]
# # a - Criar um pipeline utilizando o sklearn pipeline para o preprocessamento

# %% [markdown]
# ## Pré processamento

# %% [markdown]
# ### Substituição de nulos (nans)
#
# Existe nulos na base? é dado numérico ou categórico? qual o valor de substituição? média? valor mais frequente? etc

# %%
df.dtypes
# Out:
# data_ref                 datetime64[ns]
# index                             int64
# sexo                             object
# posse_de_veiculo                 object
# posse_de_imovel                  object
# qtd_filhos                        int64
# tipo_renda                       object
# educacao                         object
# estado_civil                     object
# tipo_residencia                  object
# idade                             int64
# tempo_emprego                   float64
# qt_pessoas_residencia           float64
# renda                           float64
# mau                                bool
# dtype: object

# %%
df = pd.read_feather('credit_scoring.ftr')
df.isnull().sum()
# Out:
# data_ref                      0
# index                         0
# sexo                          0
# posse_de_veiculo              0
# posse_de_imovel               0
# qtd_filhos                    0
# tipo_renda                    0
# educacao                      0
# estado_civil                  0
# tipo_residencia               0
# idade                         0
# tempo_emprego            125957
# qt_pessoas_residencia         0
# renda                         0
# mau                           0
# dtype: int64

# %%
#Existem valores nulos apenas na coluna tempo_emprego, irei substituir com a média dessa coluna

df['tempo_emprego'].fillna(value=df['tempo_emprego'].mean(), inplace=True)

df.isnull().sum()
# Out:
# data_ref                 0
# index                    0
# sexo                     0
# posse_de_veiculo         0
# posse_de_imovel          0
# qtd_filhos               0
# tipo_renda               0
# educacao                 0
# estado_civil             0
# tipo_residencia          0
# idade                    0
# tempo_emprego            0
# qt_pessoas_residencia    0
# renda                    0
# mau                      0
# dtype: int64

# %% [markdown]
# ### Remoção de outliers
#
# Como identificar outlier? Substituir o outlier por algum valor? Remover a linha?

# %%
#Devido à ampla variação observada na coluna 'renda', optei por considerar os valores extremos superiores e inferiores 
#como outliers. Para isso, utilizei os quartis como referência, removendo os valores muito acima e muito abaixo desses limites.

def remove_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    df_filtered = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]
    
    return df_filtered

# Aplicando a função para remover outliers na variável 'renda'
df = remove_outliers(df, 'renda')

df.shape
# Out:
# (635882, 15)

# %% [markdown]
# ### Seleção de variáveis
#
# Qual tipo de técnica? Boruta? Feature importance?

# %%
# Agrupando as classes da variável educacao

df.tipo_renda.replace(
    {'Assalariado': 'Assalariado/Bolsista',
     'Bolsista': 'Assalariado/Bolsista'}, inplace=True)

df.educacao.replace(
    {'Fundamental': 'Fund/Médio/Sup Incomp',
     'Médio': 'Fund/Médio/Sup Incomp',
     'Superior incompleto': 'Fund/Médio/Sup Incomp',
     'Superior completo': 'Sup Comp/Pós',
     'Pós graduação': 'Sup Comp/Pós'}, inplace=True)

# Categorizando a variável 'idade' em 5 bins
df['idade'] = pd.cut(df['idade'], bins=5, labels=False)

# Categorizando a variável 'tempo_emprego' em 5 bins
df['tempo_emprego'] = pd.cut(df['tempo_emprego'], bins=5, labels=False)

# Categorizando a variável 'renda' em 10 bins
df['renda'] = pd.cut(df['renda'], bins=10, labels=False)

# Exibindo o DataFrame com as novas variáveis categorizadas
df
# Out:
#          data_ref  index sexo posse_de_veiculo posse_de_imovel  qtd_filhos  \
# 0      2015-01-01   5733    F                N               N           0
# 1      2015-01-01    727    F                S               S           0
# 2      2015-01-01   6374    F                N               N           2
# 3      2015-01-01   9566    F                N               N           0
# 4      2015-01-01   9502    F                S               N           0
# ...           ...    ...  ...              ...             ...         ...
# 749995 2016-03-01  13689    M                N               S           0
# 749996 2016-03-01   7000    F                N               S           0
# 749997 2016-03-01  14023    M                S               N           2
# 749998 2016-03-01   2396    F                N               S           0
# 749999 2016-03-01  14026    M                S               N           2
#
#                   tipo_renda               educacao estado_civil  \
# 0                 Empresário  Fund/Médio/Sup Incomp     Solteiro
# 1       Assalariado/Bolsista  Fund/Médio/Sup Incomp       Casado
# 2       Assalariado/Bolsista  Fund/Médio/Sup Incomp       Casado
# 3       Assalariado/Bolsista  Fund/Médio/Sup Incomp       Casado
# 4       Assalariado/Bolsista  Fund/Médio/Sup Incomp     Solteiro
# ...                      ...                    ...          ...
# 749995            Empresário           Sup Comp/Pós       Casado
# 749996           Pensionista  Fund/Médio/Sup Incomp     Solteiro
# 749997  Assalariado/Bolsista  Fund/Médio/Sup Incomp       Casado
# 749998  Assalariado/Bolsista  Fund/Médio/Sup Incomp        Viúvo
# 749999  Assalariado/Bolsista  Fund/Médio/Sup Incomp       Casado
#
#        tipo_residencia  idade  tempo_emprego  qt_pessoas_residencia  renda  \
# 0                 Casa      2              0                    1.0      0
# 1                 Casa      1              0                    2.0      1
# 2                 Casa      0              0                    4.0      0
# 3                 Casa      3              1                    2.0      4
# 4                 Casa      0              1                    1.0      0
# ...                ...    ...            ...                    ...    ...
# 749995            Casa      2              0                    2.0      0
# 749996            Casa      4              0                    1.0      0
# 749997            Casa      2              1                    4.0      0
# 749998            Casa      3              1                    1.0      1
# 749999            Casa      2              1                    4.0      1
#
#           mau
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# ...       ...
# 749995  False
# 749996  False
# 749997   True
# 749998   True
# 749999  False
#
# [635882 rows x 15 columns]

# %%
#Selecionando variaveis

formula = '''
    mau ~ sexo + posse_de_veiculo + posse_de_imovel + qtd_filhos + tipo_renda +
    educacao + estado_civil + tipo_residencia + idade + tempo_emprego +
    renda
'''

rl = smf.glm(formula, data=df, family=sm.families.Binomial()).fit()

rl.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                       Generalized Linear Model Regression Results
# =======================================================================================
# Dep. Variable:     ['mau[False]', 'mau[True]']   No. Observations:               635882
# Model:                                     GLM   Df Residuals:                   635861
# Model Family:                         Binomial   Df Model:                           20
# Link Function:                           Logit   Scale:                          1.0000
# Method:                                   IRLS   Log-Likelihood:            -1.7668e+05
# Date:                         Wed, 21 Feb 2024   Deviance:                   3.5335e+05
# Time:                                 16:35:30   Pearson chi2:                 8.25e+05
# No. Iterations:                              7   Pseudo R-squ. (CS):            0.05212
# Covariance Type:                     nonrobust
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                            1.3334      0.038     35.436      0.000       1.260       1.407
# sexo[T.M]                            0.1021      0.011      9.602      0.000       0.081       0.123
# posse_de_veiculo[T.S]               -0.0243      0.010     -2.409      0.016      -0.044      -0.005
# posse_de_imovel[T.S]                 0.0778      0.010      8.120      0.000       0.059       0.097
# tipo_renda[T.Empresário]             0.0454      0.011      3.989      0.000       0.023       0.068
# tipo_renda[T.Pensionista]            0.0985      0.016      6.137      0.000       0.067       0.130
# tipo_renda[T.Servidor público]       0.0351      0.019      1.858      0.063      -0.002       0.072
# educacao[T.Sup Comp/Pós]             0.0500      0.011      4.702      0.000       0.029       0.071
# estado_civil[T.Separado]            -0.0430      0.019     -2.213      0.027      -0.081      -0.005
# estado_civil[T.Solteiro]            -0.0059      0.014     -0.418      0.676      -0.033       0.022
# estado_civil[T.União]               -0.0359      0.017     -2.159      0.031      -0.068      -0.003
# estado_civil[T.Viúvo]                0.0404      0.024      1.706      0.088      -0.006       0.087
# tipo_residencia[T.Casa]              0.0760      0.036      2.106      0.035       0.005       0.147
# tipo_residencia[T.Com os pais]       0.0571      0.041      1.407      0.159      -0.022       0.137
# tipo_residencia[T.Comunitário]       0.1602      0.074      2.169      0.030       0.015       0.305
# tipo_residencia[T.Estúdio]           0.0670      0.068      0.990      0.322      -0.066       0.200
# tipo_residencia[T.Governamental]     0.0476      0.043      1.095      0.273      -0.038       0.133
# qtd_filhos                           0.0003      0.006      0.042      0.967      -0.012       0.013
# idade                                0.0046      0.005      0.948      0.343      -0.005       0.014
# tempo_emprego                        0.1420      0.013     11.021      0.000       0.117       0.167
# renda                                0.4965      0.004    135.475      0.000       0.489       0.504
# ====================================================================================================
# """

# %%
formula = '''
    mau ~ sexo + posse_de_veiculo + posse_de_imovel + tipo_renda +
    educacao + tempo_emprego + renda
'''

rl = smf.glm(formula, data=df, family=sm.families.Binomial()).fit()

rl.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                       Generalized Linear Model Regression Results
# =======================================================================================
# Dep. Variable:     ['mau[False]', 'mau[True]']   No. Observations:               635882
# Model:                                     GLM   Df Residuals:                   635872
# Model Family:                         Binomial   Df Model:                            9
# Link Function:                           Logit   Scale:                          1.0000
# Method:                                   IRLS   Log-Likelihood:            -1.7669e+05
# Date:                         Wed, 21 Feb 2024   Deviance:                   3.5337e+05
# Time:                                 16:40:46   Pearson chi2:                 8.25e+05
# No. Iterations:                              7   Pseudo R-squ. (CS):            0.05208
# Covariance Type:                     nonrobust
# ==================================================================================================
#                                      coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                          1.4039      0.010    135.551      0.000       1.384       1.424
# sexo[T.M]                          0.0998      0.011      9.476      0.000       0.079       0.120
# posse_de_veiculo[T.S]             -0.0218      0.010     -2.187      0.029      -0.041      -0.002
# posse_de_imovel[T.S]               0.0828      0.009      8.867      0.000       0.065       0.101
# tipo_renda[T.Empresário]           0.0437      0.011      3.855      0.000       0.021       0.066
# tipo_renda[T.Pensionista]          0.1150      0.013      9.025      0.000       0.090       0.140
# tipo_renda[T.Servidor público]     0.0360      0.019      1.909      0.056      -0.001       0.073
# educacao[T.Sup Comp/Pós]           0.0493      0.011      4.681      0.000       0.029       0.070
# tempo_emprego                      0.1436      0.013     11.224      0.000       0.118       0.169
# renda                              0.4968      0.004    135.624      0.000       0.490       0.504
# ==================================================================================================
# """

# %% [markdown]
# ### Redução de dimensionalidade (PCA)
#
# Aplicar PCA para reduzir a dimensionalidade para 5

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Selecionar apenas as colunas numéricas do DataFrame
numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns
X = df[numeric_cols]

# Padronize os dados
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Aplique o PCA
pca = PCA(n_components=5)
X_pca = pca.fit_transform(X_scaled)

# X_pca agora contém as características reduzidas

X_pca
# Out:
# array([[-1.35279979, -0.98494935,  0.51405937, -0.50222367,  0.31957832],
#        [-0.39174831, -0.67039578,  1.52563942, -0.91028792, -0.14120794],
#        [ 3.12514136, -1.13543499,  0.65280692, -0.10826152,  0.14698382],
#        ...,
#        [ 2.72462557,  0.293276  , -0.92656134,  0.94220852,  1.91420108],
#        [-1.55635222,  0.84818032,  1.09964255, -0.33482651,  1.55573312],
#        [ 2.72024532,  0.59144631, -0.95315847,  0.98911402,  1.62099589]])

# %% [markdown]
# ### Criação de dummies
#
# Aplicar o get_dummies() ou onehotencoder() para transformar colunas catégoricas do dataframe em colunas de 0 e 1.
# - sexo
# - posse_de_veiculo
# - posse_de_imovel
# - tipo_renda
# - educacao
# - estado_civil
# - tipo_residencia

# %%
# Selecionar as colunas categóricas do DataFrame
categorical_cols = ['sexo', 'posse_de_veiculo', 'posse_de_imovel', 'tipo_renda', 'educacao', 'estado_civil', 'tipo_residencia']

# Aplicar get_dummies para cada coluna categórica
df_encoded = pd.get_dummies(df, columns=categorical_cols)

# Visualizar o DataFrame com colunas one-hot encoded
df_encoded
# Out:
#          data_ref  index  qtd_filhos  idade  tempo_emprego  \
# 0      2015-01-01   5733           0      2              0
# 1      2015-01-01    727           0      1              0
# 2      2015-01-01   6374           2      0              0
# 3      2015-01-01   9566           0      3              1
# 4      2015-01-01   9502           0      0              1
# ...           ...    ...         ...    ...            ...
# 749995 2016-03-01  13689           0      2              0
# 749996 2016-03-01   7000           0      4              0
# 749997 2016-03-01  14023           2      2              1
# 749998 2016-03-01   2396           0      3              1
# 749999 2016-03-01  14026           2      2              1
#
#         qt_pessoas_residencia  renda    mau  sexo_F  sexo_M  ...  \
# 0                         1.0      0  False    True   False  ...
# 1                         2.0      1  False    True   False  ...
# 2                         4.0      0  False    True   False  ...
# 3                         2.0      4  False    True   False  ...
# 4                         1.0      0  False    True   False  ...
# ...                       ...    ...    ...     ...     ...  ...
# 749995                    2.0      0  False   False    True  ...
# 749996                    1.0      0  False    True   False  ...
# 749997                    4.0      0   True   False    True  ...
# 749998                    1.0      1   True    True   False  ...
# 749999                    4.0      1  False   False    True  ...
#
#         estado_civil_Separado  estado_civil_Solteiro  estado_civil_União  \
# 0                       False                   True               False
# 1                       False                  False               False
# 2                       False                  False               False
# 3                       False                  False               False
# 4                       False                   True               False
# ...                       ...                    ...                 ...
# 749995                  False                  False               False
# 749996                  False                   True               False
# 749997                  False                  False               False
# 749998                  False                  False               False
# 749999                  False                  False               False
#
#         estado_civil_Viúvo  tipo_residencia_Aluguel  tipo_residencia_Casa  \
# 0                    False                    False                  True
# 1                    False                    False                  True
# 2                    False                    False                  True
# 3                    False                    False                  True
# 4                    False                    False                  True
# ...                    ...                      ...                   ...
# 749995               False                    False                  True
# 749996               False                    False                  True
# 749997               False                    False                  True
# 749998                True                    False                  True
# 749999               False                    False                  True
#
#         tipo_residencia_Com os pais  tipo_residencia_Comunitário  \
# 0                             False                        False
# 1                             False                        False
# 2                             False                        False
# 3                             False                        False
# 4                             False                        False
# ...                             ...                          ...
# 749995                        False                        False
# 749996                        False                        False
# 749997                        False                        False
# 749998                        False                        False
# 749999                        False                        False
#
#         tipo_residencia_Estúdio  tipo_residencia_Governamental
# 0                         False                          False
# 1                         False                          False
# 2                         False                          False
# 3                         False                          False
# 4                         False                          False
# ...                         ...                            ...
# 749995                    False                          False
# 749996                    False                          False
# 749997                    False                          False
# 749998                    False                          False
# 749999                    False                          False
#
# [635882 rows x 31 columns]

# %% [markdown]
# ### Pipeline
#
# Crie um pipeline contendo essas funções.
#
# preprocessamento()
# - substituicao de nulos
# - remoção outliers
# - PCA
# - Criação de dummy de pelo menos 1 variável (posse_de_veiculo)

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.decomposition import PCA
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import FeatureUnion
from sklearn.compose import make_column_selector as selector

# Função para retornar colunas numéricas e categóricas
def get_numeric_and_categorical_cols(df):
    numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns
    categorical_cols = df.select_dtypes(include=['object']).columns
    return numeric_cols, categorical_cols

# Função para criar o pipeline de pré-processamento
def preprocessamento(df):
    # Separar colunas numéricas e categóricas
    numeric_cols, categorical_cols = get_numeric_and_categorical_cols(df)
    
    # Pipeline para colunas numéricas
    numeric_transformer = Pipeline([
        ('imputer', SimpleImputer(strategy='mean')),  # Substituição de nulos
        ('scaler', StandardScaler()),  # Padronização
        ('pca', PCA(n_components=5))  # PCA
    ])
    
    # Pipeline para colunas categóricas
    categorical_transformer = Pipeline([
        ('imputer', SimpleImputer(strategy='most_frequent')),  # Substituição de nulos
        ('onehot', OneHotEncoder(drop='first'))  # One-hot encoding
    ])
    
    # Combinar os pipelines de colunas numéricas e categóricas
    preprocessor = ColumnTransformer([
        ('num', numeric_transformer, numeric_cols),
        ('cat', categorical_transformer, categorical_cols)
    ])
    
    # Pipeline final
    pipeline = Pipeline([
        ('preprocessor', preprocessor)
    ])
    
    return pipeline

# Exemplo de uso
pipeline = preprocessamento(df)
X_preprocessed = pipeline.fit_transform(df)

# %% [markdown]
# # b - Pycaret na base de dados
#
# Utilize o pycaret para pre processar os dados e rodar o modelo **lightgbm**. Faça todos os passos a passos da aula e gere os gráficos finais. E o pipeline de toda a transformação.

# %%
from pycaret.classification import *

# Carregue os dados
data = pd.read_feather('credit_scoring.ftr')

# Inicialize o ambiente do PyCaret
exp1 = setup(data, target='mau')
# Out:
# <style type="text/css">
# #T_9dc26_row11_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_9dc26">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9dc26_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_9dc26_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9dc26_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9dc26_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_9dc26_row0_col1" class="data row0 col1" >6420</td>
#     </tr>
#     <tr>
#       <th id="T_9dc26_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9dc26_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_9dc26_row1_col1" class="data row1 col1" >mau</td>
#     </tr>
#     <tr>
#       <th id="T_9dc26_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9dc26_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_9dc26_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_9dc26_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9dc26_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_9dc26_row3_col1" class="data row3 col1" >(750000, 15)</td>
#     </tr>
#     <tr>
#       <th id="T_9dc26_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9dc26_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_9dc26_row4_col1" class="data row4 col1" >(750000, 34)</td>
#     </tr>
#     <tr>
#       <th id="T_9dc26_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9dc26_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_9dc26_row5_col1" class="data row5 col1" >(525000, 34)</td>
#     </tr>
#     <tr>
#       <th id="T_9dc26_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9dc26_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_9dc26_row6_col1" class="data row6 col1" >(225000, 34)</td>
#     </tr>
#     <tr>
#       <th id="T_9dc26_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9dc26_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_9dc26_row7_col1" class="data row7 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_9dc26_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9dc26_row8_col0" class="data row8 col0" >Date features</td>
#       <td id="T_9dc26_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_9dc26_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9dc26_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_9dc26_row9_col1" class="data row9 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_9dc26_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_9dc26_row10_col0" class="data row10 col0" >Rows with missing values</td>
#       <td id="T_9dc26_row10_col1" class="data row10 col1" >16.8%</td>
#     </tr>
#     <tr>
#       <th id="T_9dc26_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_9dc26_row11_col0" class="data row11 col0" >Preprocess</td>
#       <td id="T_9dc26_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_9dc26_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_9dc26_row12_col0" class="data row12 col0" >Imputation type</td>
#       <td id="T_9dc26_row12_col1" class="data row12 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_9dc26_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_9dc26_row13_col0" class="data row13 col0" >Numeric imputation</td>
#       <td id="T_9dc26_row13_col1" class="data row13 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_9dc26_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_9dc26_row14_col0" class="data row14 col0" >Categorical imputation</td>
#       <td id="T_9dc26_row14_col1" class="data row14 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_9dc26_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_9dc26_row15_col0" class="data row15 col0" >Maximum one-hot encoding</td>
#       <td id="T_9dc26_row15_col1" class="data row15 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_9dc26_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_9dc26_row16_col0" class="data row16 col0" >Encoding method</td>
#       <td id="T_9dc26_row16_col1" class="data row16 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_9dc26_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_9dc26_row17_col0" class="data row17 col0" >Fold Generator</td>
#       <td id="T_9dc26_row17_col1" class="data row17 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_9dc26_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_9dc26_row18_col0" class="data row18 col0" >Fold Number</td>
#       <td id="T_9dc26_row18_col1" class="data row18 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_9dc26_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_9dc26_row19_col0" class="data row19 col0" >CPU Jobs</td>
#       <td id="T_9dc26_row19_col1" class="data row19 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_9dc26_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_9dc26_row20_col0" class="data row20 col0" >Use GPU</td>
#       <td id="T_9dc26_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9dc26_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_9dc26_row21_col0" class="data row21 col0" >Log Experiment</td>
#       <td id="T_9dc26_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9dc26_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_9dc26_row22_col0" class="data row22 col0" >Experiment Name</td>
#       <td id="T_9dc26_row22_col1" class="data row22 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_9dc26_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_9dc26_row23_col0" class="data row23 col0" >USI</td>
#       <td id="T_9dc26_row23_col1" class="data row23 col1" >6fcd</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_7c3d4 th {
#   text-align: left;
# }
# #T_7c3d4_row0_col0, #T_7c3d4_row0_col3, #T_7c3d4_row0_col5, #T_7c3d4_row0_col6, #T_7c3d4_row0_col7, #T_7c3d4_row1_col0, #T_7c3d4_row1_col3, #T_7c3d4_row1_col4, #T_7c3d4_row1_col5, #T_7c3d4_row1_col6, #T_7c3d4_row1_col7, #T_7c3d4_row2_col0, #T_7c3d4_row2_col1, #T_7c3d4_row2_col3, #T_7c3d4_row2_col4, #T_7c3d4_row2_col5, #T_7c3d4_row2_col6, #T_7c3d4_row2_col7, #T_7c3d4_row3_col0, #T_7c3d4_row3_col1, #T_7c3d4_row3_col3, #T_7c3d4_row3_col4, #T_7c3d4_row3_col5, #T_7c3d4_row3_col6, #T_7c3d4_row3_col7, #T_7c3d4_row4_col0, #T_7c3d4_row4_col1, #T_7c3d4_row4_col3, #T_7c3d4_row4_col4, #T_7c3d4_row4_col5, #T_7c3d4_row4_col6, #T_7c3d4_row4_col7, #T_7c3d4_row5_col0, #T_7c3d4_row5_col1, #T_7c3d4_row5_col3, #T_7c3d4_row5_col4, #T_7c3d4_row5_col5, #T_7c3d4_row5_col6, #T_7c3d4_row5_col7, #T_7c3d4_row6_col0, #T_7c3d4_row6_col1, #T_7c3d4_row6_col3, #T_7c3d4_row6_col4, #T_7c3d4_row6_col5, #T_7c3d4_row6_col6, #T_7c3d4_row6_col7, #T_7c3d4_row7_col0, #T_7c3d4_row7_col1, #T_7c3d4_row7_col3, #T_7c3d4_row7_col4, #T_7c3d4_row7_col5, #T_7c3d4_row7_col6, #T_7c3d4_row7_col7, #T_7c3d4_row8_col0, #T_7c3d4_row8_col1, #T_7c3d4_row8_col3, #T_7c3d4_row8_col4, #T_7c3d4_row8_col5, #T_7c3d4_row8_col6, #T_7c3d4_row8_col7, #T_7c3d4_row9_col0, #T_7c3d4_row9_col1, #T_7c3d4_row9_col3, #T_7c3d4_row9_col4, #T_7c3d4_row9_col5, #T_7c3d4_row9_col7, #T_7c3d4_row10_col0, #T_7c3d4_row10_col1, #T_7c3d4_row10_col3, #T_7c3d4_row10_col4, #T_7c3d4_row10_col5, #T_7c3d4_row10_col6, #T_7c3d4_row10_col7, #T_7c3d4_row11_col0, #T_7c3d4_row11_col1, #T_7c3d4_row11_col3, #T_7c3d4_row11_col4, #T_7c3d4_row11_col5, #T_7c3d4_row11_col6, #T_7c3d4_row11_col7, #T_7c3d4_row12_col0, #T_7c3d4_row12_col1, #T_7c3d4_row12_col3, #T_7c3d4_row12_col4, #T_7c3d4_row12_col6, #T_7c3d4_row13_col0, #T_7c3d4_row13_col1, #T_7c3d4_row13_col4, #T_7c3d4_row13_col5, #T_7c3d4_row13_col6, #T_7c3d4_row13_col7 {
#   text-align: left;
# }
# #T_7c3d4_row0_col1, #T_7c3d4_row0_col2, #T_7c3d4_row0_col4, #T_7c3d4_row1_col1, #T_7c3d4_row1_col2, #T_7c3d4_row2_col2, #T_7c3d4_row3_col2, #T_7c3d4_row4_col2, #T_7c3d4_row5_col2, #T_7c3d4_row6_col2, #T_7c3d4_row7_col2, #T_7c3d4_row8_col2, #T_7c3d4_row9_col2, #T_7c3d4_row9_col6, #T_7c3d4_row10_col2, #T_7c3d4_row11_col2, #T_7c3d4_row12_col2, #T_7c3d4_row12_col5, #T_7c3d4_row12_col7, #T_7c3d4_row13_col2, #T_7c3d4_row13_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_7c3d4_row0_col8, #T_7c3d4_row1_col8, #T_7c3d4_row2_col8, #T_7c3d4_row3_col8, #T_7c3d4_row4_col8, #T_7c3d4_row5_col8, #T_7c3d4_row7_col8, #T_7c3d4_row8_col8, #T_7c3d4_row9_col8, #T_7c3d4_row10_col8, #T_7c3d4_row11_col8, #T_7c3d4_row12_col8, #T_7c3d4_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_7c3d4_row6_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_7c3d4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7c3d4_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_7c3d4_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_7c3d4_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_7c3d4_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_7c3d4_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_7c3d4_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_7c3d4_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_7c3d4_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_7c3d4_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c3d4_level0_row0" class="row_heading level0 row0" >ada</th>
#       <td id="T_7c3d4_row0_col0" class="data row0 col0" >Ada Boost Classifier</td>
#       <td id="T_7c3d4_row0_col1" class="data row0 col1" >0.9221</td>
#       <td id="T_7c3d4_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_7c3d4_row0_col3" class="data row0 col3" >0.0257</td>
#       <td id="T_7c3d4_row0_col4" class="data row0 col4" >0.5546</td>
#       <td id="T_7c3d4_row0_col5" class="data row0 col5" >0.0488</td>
#       <td id="T_7c3d4_row0_col6" class="data row0 col6" >0.0421</td>
#       <td id="T_7c3d4_row0_col7" class="data row0 col7" >0.1043</td>
#       <td id="T_7c3d4_row0_col8" class="data row0 col8" >13.5220</td>
#     </tr>
#     <tr>
#       <th id="T_7c3d4_level0_row1" class="row_heading level0 row1" >gbc</th>
#       <td id="T_7c3d4_row1_col0" class="data row1 col0" >Gradient Boosting Classifier</td>
#       <td id="T_7c3d4_row1_col1" class="data row1 col1" >0.9221</td>
#       <td id="T_7c3d4_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_7c3d4_row1_col3" class="data row1 col3" >0.0217</td>
#       <td id="T_7c3d4_row1_col4" class="data row1 col4" >0.5421</td>
#       <td id="T_7c3d4_row1_col5" class="data row1 col5" >0.0418</td>
#       <td id="T_7c3d4_row1_col6" class="data row1 col6" >0.0359</td>
#       <td id="T_7c3d4_row1_col7" class="data row1 col7" >0.0966</td>
#       <td id="T_7c3d4_row1_col8" class="data row1 col8" >84.3480</td>
#     </tr>
#     <tr>
#       <th id="T_7c3d4_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_7c3d4_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_7c3d4_row2_col1" class="data row2 col1" >0.9220</td>
#       <td id="T_7c3d4_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_7c3d4_row2_col3" class="data row2 col3" >0.0249</td>
#       <td id="T_7c3d4_row2_col4" class="data row2 col4" >0.5257</td>
#       <td id="T_7c3d4_row2_col5" class="data row2 col5" >0.0476</td>
#       <td id="T_7c3d4_row2_col6" class="data row2 col6" >0.0408</td>
#       <td id="T_7c3d4_row2_col7" class="data row2 col7" >0.1016</td>
#       <td id="T_7c3d4_row2_col8" class="data row2 col8" >3.4860</td>
#     </tr>
#     <tr>
#       <th id="T_7c3d4_level0_row3" class="row_heading level0 row3" >lr</th>
#       <td id="T_7c3d4_row3_col0" class="data row3 col0" >Logistic Regression</td>
#       <td id="T_7c3d4_row3_col1" class="data row3 col1" >0.9218</td>
#       <td id="T_7c3d4_row3_col2" class="data row3 col2" >0.0000</td>
#       <td id="T_7c3d4_row3_col3" class="data row3 col3" >0.0000</td>
#       <td id="T_7c3d4_row3_col4" class="data row3 col4" >0.0000</td>
#       <td id="T_7c3d4_row3_col5" class="data row3 col5" >0.0000</td>
#       <td id="T_7c3d4_row3_col6" class="data row3 col6" >0.0000</td>
#       <td id="T_7c3d4_row3_col7" class="data row3 col7" >0.0000</td>
#       <td id="T_7c3d4_row3_col8" class="data row3 col8" >28.8980</td>
#     </tr>
#     <tr>
#       <th id="T_7c3d4_level0_row4" class="row_heading level0 row4" >ridge</th>
#       <td id="T_7c3d4_row4_col0" class="data row4 col0" >Ridge Classifier</td>
#       <td id="T_7c3d4_row4_col1" class="data row4 col1" >0.9218</td>
#       <td id="T_7c3d4_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_7c3d4_row4_col3" class="data row4 col3" >0.0000</td>
#       <td id="T_7c3d4_row4_col4" class="data row4 col4" >0.0000</td>
#       <td id="T_7c3d4_row4_col5" class="data row4 col5" >0.0000</td>
#       <td id="T_7c3d4_row4_col6" class="data row4 col6" >0.0000</td>
#       <td id="T_7c3d4_row4_col7" class="data row4 col7" >0.0000</td>
#       <td id="T_7c3d4_row4_col8" class="data row4 col8" >2.1210</td>
#     </tr>
#     <tr>
#       <th id="T_7c3d4_level0_row5" class="row_heading level0 row5" >lda</th>
#       <td id="T_7c3d4_row5_col0" class="data row5 col0" >Linear Discriminant Analysis</td>
#       <td id="T_7c3d4_row5_col1" class="data row5 col1" >0.9218</td>
#       <td id="T_7c3d4_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_7c3d4_row5_col3" class="data row5 col3" >0.0000</td>
#       <td id="T_7c3d4_row5_col4" class="data row5 col4" >0.0000</td>
#       <td id="T_7c3d4_row5_col5" class="data row5 col5" >0.0000</td>
#       <td id="T_7c3d4_row5_col6" class="data row5 col6" >0.0000</td>
#       <td id="T_7c3d4_row5_col7" class="data row5 col7" >0.0000</td>

# %%
lightgbm = create_model('lightgbm')
# Out:
# <style type="text/css">
# #T_9e4cb_row10_col0, #T_9e4cb_row10_col1, #T_9e4cb_row10_col2, #T_9e4cb_row10_col3, #T_9e4cb_row10_col4, #T_9e4cb_row10_col5, #T_9e4cb_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_9e4cb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9e4cb_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_9e4cb_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_9e4cb_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_9e4cb_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_9e4cb_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_9e4cb_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_9e4cb_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9e4cb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9e4cb_row0_col0" class="data row0 col0" >0.9217</td>
#       <td id="T_9e4cb_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_9e4cb_row0_col2" class="data row0 col2" >0.0195</td>
#       <td id="T_9e4cb_row0_col3" class="data row0 col3" >0.4819</td>
#       <td id="T_9e4cb_row0_col4" class="data row0 col4" >0.0375</td>
#       <td id="T_9e4cb_row0_col5" class="data row0 col5" >0.0316</td>
#       <td id="T_9e4cb_row0_col6" class="data row0 col6" >0.0847</td>
#     </tr>
#     <tr>
#       <th id="T_9e4cb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9e4cb_row1_col0" class="data row1 col0" >0.9221</td>
#       <td id="T_9e4cb_row1_col1" class="data row1 col1" >0.0000</td>
#       <td id="T_9e4cb_row1_col2" class="data row1 col2" >0.0261</td>
#       <td id="T_9e4cb_row1_col3" class="data row1 col3" >0.5377</td>
#       <td id="T_9e4cb_row1_col4" class="data row1 col4" >0.0497</td>
#       <td id="T_9e4cb_row1_col5" class="data row1 col5" >0.0428</td>
#       <td id="T_9e4cb_row1_col6" class="data row1 col6" >0.1056</td>
#     </tr>
#     <tr>
#       <th id="T_9e4cb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9e4cb_row2_col0" class="data row2 col0" >0.9219</td>
#       <td id="T_9e4cb_row2_col1" class="data row2 col1" >0.0000</td>
#       <td id="T_9e4cb_row2_col2" class="data row2 col2" >0.0239</td>
#       <td id="T_9e4cb_row2_col3" class="data row2 col3" >0.5104</td>
#       <td id="T_9e4cb_row2_col4" class="data row2 col4" >0.0456</td>
#       <td id="T_9e4cb_row2_col5" class="data row2 col5" >0.0389</td>
#       <td id="T_9e4cb_row2_col6" class="data row2 col6" >0.0975</td>
#     </tr>
#     <tr>
#       <th id="T_9e4cb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9e4cb_row3_col0" class="data row3 col0" >0.9219</td>
#       <td id="T_9e4cb_row3_col1" class="data row3 col1" >0.0000</td>
#       <td id="T_9e4cb_row3_col2" class="data row3 col2" >0.0241</td>
#       <td id="T_9e4cb_row3_col3" class="data row3 col3" >0.5156</td>
#       <td id="T_9e4cb_row3_col4" class="data row3 col4" >0.0461</td>
#       <td id="T_9e4cb_row3_col5" class="data row3 col5" >0.0394</td>
#       <td id="T_9e4cb_row3_col6" class="data row3 col6" >0.0987</td>
#     </tr>
#     <tr>
#       <th id="T_9e4cb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9e4cb_row4_col0" class="data row4 col0" >0.9222</td>
#       <td id="T_9e4cb_row4_col1" class="data row4 col1" >0.0000</td>
#       <td id="T_9e4cb_row4_col2" class="data row4 col2" >0.0239</td>
#       <td id="T_9e4cb_row4_col3" class="data row4 col3" >0.5537</td>
#       <td id="T_9e4cb_row4_col4" class="data row4 col4" >0.0458</td>
#       <td id="T_9e4cb_row4_col5" class="data row4 col5" >0.0396</td>
#       <td id="T_9e4cb_row4_col6" class="data row4 col6" >0.1030</td>
#     </tr>
#     <tr>
#       <th id="T_9e4cb_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9e4cb_row5_col0" class="data row5 col0" >0.9216</td>
#       <td id="T_9e4cb_row5_col1" class="data row5 col1" >0.0000</td>
#       <td id="T_9e4cb_row5_col2" class="data row5 col2" >0.0244</td>
#       <td id="T_9e4cb_row5_col3" class="data row5 col3" >0.4695</td>
#       <td id="T_9e4cb_row5_col4" class="data row5 col4" >0.0463</td>
#       <td id="T_9e4cb_row5_col5" class="data row5 col5" >0.0389</td>
#       <td id="T_9e4cb_row5_col6" class="data row5 col6" >0.0930</td>
#     </tr>
#     <tr>
#       <th id="T_9e4cb_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9e4cb_row6_col0" class="data row6 col0" >0.9221</td>
#       <td id="T_9e4cb_row6_col1" class="data row6 col1" >0.0000</td>
#       <td id="T_9e4cb_row6_col2" class="data row6 col2" >0.0270</td>
#       <td id="T_9e4cb_row6_col3" class="data row6 col3" >0.5388</td>
#       <td id="T_9e4cb_row6_col4" class="data row6 col4" >0.0515</td>
#       <td id="T_9e4cb_row6_col5" class="data row6 col5" >0.0444</td>
#       <td id="T_9e4cb_row6_col6" class="data row6 col6" >0.1077</td>
#     </tr>
#     <tr>
#       <th id="T_9e4cb_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9e4cb_row7_col0" class="data row7 col0" >0.9227</td>
#       <td id="T_9e4cb_row7_col1" class="data row7 col1" >0.0000</td>
#       <td id="T_9e4cb_row7_col2" class="data row7 col2" >0.0292</td>
#       <td id="T_9e4cb_row7_col3" class="data row7 col3" >0.6186</td>
#       <td id="T_9e4cb_row7_col4" class="data row7 col4" >0.0558</td>
#       <td id="T_9e4cb_row7_col5" class="data row7 col5" >0.0491</td>
#       <td id="T_9e4cb_row7_col6" class="data row7 col6" >0.1226</td>
#     </tr>
#     <tr>
#       <th id="T_9e4cb_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9e4cb_row8_col0" class="data row8 col0" >0.9220</td>
#       <td id="T_9e4cb_row8_col1" class="data row8 col1" >0.0000</td>
#       <td id="T_9e4cb_row8_col2" class="data row8 col2" >0.0287</td>
#       <td id="T_9e4cb_row8_col3" class="data row8 col3" >0.5198</td>
#       <td id="T_9e4cb_row8_col4" class="data row8 col4" >0.0545</td>
#       <td id="T_9e4cb_row8_col5" class="data row8 col5" >0.0467</td>
#       <td id="T_9e4cb_row8_col6" class="data row8 col6" >0.1084</td>
#     </tr>
#     <tr>
#       <th id="T_9e4cb_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9e4cb_row9_col0" class="data row9 col0" >0.9219</td>
#       <td id="T_9e4cb_row9_col1" class="data row9 col1" >0.0000</td>
#       <td id="T_9e4cb_row9_col2" class="data row9 col2" >0.0224</td>
#       <td id="T_9e4cb_row9_col3" class="data row9 col3" >0.5111</td>
#       <td id="T_9e4cb_row9_col4" class="data row9 col4" >0.0429</td>
#       <td id="T_9e4cb_row9_col5" class="data row9 col5" >0.0366</td>
#       <td id="T_9e4cb_row9_col6" class="data row9 col6" >0.0946</td>
#     </tr>
#     <tr>
#       <th id="T_9e4cb_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_9e4cb_row10_col0" class="data row10 col0" >0.9220</td>
#       <td id="T_9e4cb_row10_col1" class="data row10 col1" >0.0000</td>
#       <td id="T_9e4cb_row10_col2" class="data row10 col2" >0.0249</td>
#       <td id="T_9e4cb_row10_col3" class="data row10 col3" >0.5257</td>
#       <td id="T_9e4cb_row10_col4" class="data row10 col4" >0.0476</td>
#       <td id="T_9e4cb_row10_col5" class="data row10 col5" >0.0408</td>
#       <td id="T_9e4cb_row10_col6" class="data row10 col6" >0.1016</td>
#     </tr>
#     <tr>
#       <th id="T_9e4cb_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_9e4cb_row11_col0" class="data row11 col0" >0.0003</td>
#       <td id="T_9e4cb_row11_col1" class="data row11 col1" >0.0000</td>
#       <td id="T_9e4cb_row11_col2" class="data row11 col2" >0.0028</td>
#       <td id="T_9e4cb_row11_col3" class="data row11 col3" >0.0392</td>
#       <td id="T_9e4cb_row11_col4

# %%
evaluate_model(lightgbm)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
tuned_lightgbm = tune_model(lightgbm)
# Out:
# <style type="text/css">
# #T_8655a_row10_col0, #T_8655a_row10_col1, #T_8655a_row10_col2, #T_8655a_row10_col3, #T_8655a_row10_col4, #T_8655a_row10_col5, #T_8655a_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_8655a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8655a_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_8655a_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_8655a_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_8655a_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_8655a_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_8655a_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_8655a_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8655a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8655a_row0_col0" class="data row0 col0" >0.9219</td>
#       <td id="T_8655a_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_8655a_row0_col2" class="data row0 col2" >0.0229</td>
#       <td id="T_8655a_row0_col3" class="data row0 col3" >0.5081</td>
#       <td id="T_8655a_row0_col4" class="data row0 col4" >0.0438</td>
#       <td id="T_8655a_row0_col5" class="data row0 col5" >0.0373</td>
#       <td id="T_8655a_row0_col6" class="data row0 col6" >0.0952</td>
#     </tr>
#     <tr>
#       <th id="T_8655a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8655a_row1_col0" class="data row1 col0" >0.9225</td>
#       <td id="T_8655a_row1_col1" class="data row1 col1" >0.0000</td>
#       <td id="T_8655a_row1_col2" class="data row1 col2" >0.0309</td>
#       <td id="T_8655a_row1_col3" class="data row1 col3" >0.5773</td>
#       <td id="T_8655a_row1_col4" class="data row1 col4" >0.0587</td>
#       <td id="T_8655a_row1_col5" class="data row1 col5" >0.0512</td>
#       <td id="T_8655a_row1_col6" class="data row1 col6" >0.1206</td>
#     </tr>
#     <tr>
#       <th id="T_8655a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8655a_row2_col0" class="data row2 col0" >0.9219</td>
#       <td id="T_8655a_row2_col1" class="data row2 col1" >0.0000</td>
#       <td id="T_8655a_row2_col2" class="data row2 col2" >0.0244</td>
#       <td id="T_8655a_row2_col3" class="data row2 col3" >0.5155</td>
#       <td id="T_8655a_row2_col4" class="data row2 col4" >0.0465</td>
#       <td id="T_8655a_row2_col5" class="data row2 col5" >0.0397</td>
#       <td id="T_8655a_row2_col6" class="data row2 col6" >0.0992</td>
#     </tr>
#     <tr>
#       <th id="T_8655a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8655a_row3_col0" class="data row3 col0" >0.9220</td>
#       <td id="T_8655a_row3_col1" class="data row3 col1" >0.0000</td>
#       <td id="T_8655a_row3_col2" class="data row3 col2" >0.0263</td>
#       <td id="T_8655a_row3_col3" class="data row3 col3" >0.5243</td>
#       <td id="T_8655a_row3_col4" class="data row3 col4" >0.0501</td>
#       <td id="T_8655a_row3_col5" class="data row3 col5" >0.0430</td>
#       <td id="T_8655a_row3_col6" class="data row3 col6" >0.1043</td>
#     </tr>
#     <tr>
#       <th id="T_8655a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8655a_row4_col0" class="data row4 col0" >0.9224</td>
#       <td id="T_8655a_row4_col1" class="data row4 col1" >0.0000</td>
#       <td id="T_8655a_row4_col2" class="data row4 col2" >0.0275</td>
#       <td id="T_8655a_row4_col3" class="data row4 col3" >0.5795</td>
#       <td id="T_8655a_row4_col4" class="data row4 col4" >0.0526</td>
#       <td id="T_8655a_row4_col5" class="data row4 col5" >0.0458</td>
#       <td id="T_8655a_row4_col6" class="data row4 col6" >0.1140</td>
#     </tr>
#     <tr>
#       <th id="T_8655a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8655a_row5_col0" class="data row5 col0" >0.9216</td>
#       <td id="T_8655a_row5_col1" class="data row5 col1" >0.0000</td>
#       <td id="T_8655a_row5_col2" class="data row5 col2" >0.0248</td>
#       <td id="T_8655a_row5_col3" class="data row5 col3" >0.4744</td>
#       <td id="T_8655a_row5_col4" class="data row5 col4" >0.0472</td>
#       <td id="T_8655a_row5_col5" class="data row5 col5" >0.0397</td>
#       <td id="T_8655a_row5_col6" class="data row5 col6" >0.0946</td>
#     </tr>
#     <tr>
#       <th id="T_8655a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8655a_row6_col0" class="data row6 col0" >0.9224</td>
#       <td id="T_8655a_row6_col1" class="data row6 col1" >0.0000</td>
#       <td id="T_8655a_row6_col2" class="data row6 col2" >0.0290</td>
#       <td id="T_8655a_row6_col3" class="data row6 col3" >0.5694</td>
#       <td id="T_8655a_row6_col4" class="data row6 col4" >0.0552</td>
#       <td id="T_8655a_row6_col5" class="data row6 col5" >0.0480</td>
#       <td id="T_8655a_row6_col6" class="data row6 col6" >0.1157</td>
#     </tr>
#     <tr>
#       <th id="T_8655a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8655a_row7_col0" class="data row7 col0" >0.9229</td>
#       <td id="T_8655a_row7_col1" class="data row7 col1" >0.0000</td>
#       <td id="T_8655a_row7_col2" class="data row7 col2" >0.0326</td>
#       <td id="T_8655a_row7_col3" class="data row7 col3" >0.6321</td>
#       <td id="T_8655a_row7_col4" class="data row7 col4" >0.0621</td>
#       <td id="T_8655a_row7_col5" class="data row7 col5" >0.0548</td>
#       <td id="T_8655a_row7_col6" class="data row7 col6" >0.1314</td>
#     </tr>
#     <tr>
#       <th id="T_8655a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8655a_row8_col0" class="data row8 col0" >0.9221</td>
#       <td id="T_8655a_row8_col1" class="data row8 col1" >0.0000</td>
#       <td id="T_8655a_row8_col2" class="data row8 col2" >0.0285</td>
#       <td id="T_8655a_row8_col3" class="data row8 col3" >0.5318</td>
#       <td id="T_8655a_row8_col4" class="data row8 col4" >0.0541</td>
#       <td id="T_8655a_row8_col5" class="data row8 col5" >0.0465</td>
#       <td id="T_8655a_row8_col6" class="data row8 col6" >0.1096</td>
#     </tr>
#     <tr>
#       <th id="T_8655a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8655a_row9_col0" class="data row9 col0" >0.9221</td>
#       <td id="T_8655a_row9_col1" class="data row9 col1" >0.0000</td>
#       <td id="T_8655a_row9_col2" class="data row9 col2" >0.0283</td>
#       <td id="T_8655a_row9_col3" class="data row9 col3" >0.5370</td>
#       <td id="T_8655a_row9_col4" class="data row9 col4" >0.0537</td>
#       <td id="T_8655a_row9_col5" class="data row9 col5" >0.0462</td>
#       <td id="T_8655a_row9_col6" class="data row9 col6" >0.1099</td>
#     </tr>
#     <tr>
#       <th id="T_8655a_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_8655a_row10_col0" class="data row10 col0" >0.9222</td>
#       <td id="T_8655a_row10_col1" class="data row10 col1" >0.0000</td>
#       <td id="T_8655a_row10_col2" class="data row10 col2" >0.0275</td>
#       <td id="T_8655a_row10_col3" class="data row10 col3" >0.5449</td>
#       <td id="T_8655a_row10_col4" class="data row10 col4" >0.0524</td>
#       <td id="T_8655a_row10_col5" class="data row10 col5" >0.0452</td>
#       <td id="T_8655a_row10_col6" class="data row10 col6" >0.1094</td>
#     </tr>
#     <tr>
#       <th id="T_8655a_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_8655a_row11_col0" class="data row11 col0" >0.0003</td>
#       <td id="T_8655a_row11_col1" class="data row11 col1" >0.0000</td>
#       <td id="T_8655a_row11_col2" class="data row11 col2" >0.0029</td>
#       <td id="T_8655a_row11_col3" class="data row11 col3" >0.0428</td>
#       <td id="T_8655a_row11_col4
# Fitting 10 folds for each of 10 candidates, totalling 100 fits

# %%
plot_model(tuned_lightgbm, plot='confusion_matrix')
plot_model(tuned_lightgbm, plot='feature')

# %% [markdown]
# ## Estrutura final do pipeline:

# %%
# Inicialize o ambiente do PyCaret
setup(data, target='mau')

# Compare modelos e selecione o LightGBM
best = compare_models()

# Crie o modelo LightGBM
lightgbm = create_model('lightgbm')

# Avalie o desempenho do modelo
evaluate_model(lightgbm)

# Ajuste o modelo
tuned_lightgbm = tune_model(lightgbm)

# Plote os gráficos finais
plot_model(tuned_lightgbm, plot='confusion_matrix')
plot_model(tuned_lightgbm, plot='feature')
